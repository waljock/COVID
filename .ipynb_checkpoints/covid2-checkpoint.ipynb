# %%
import pandas as pd
import os
import seaborn as sb
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt


from bokeh.plotting import figure, show, output_file
from bokeh.models import ColumnDataSource, Range1d, LabelSet, Label, Title
from bokeh.io import output_notebook
from bokeh.models.tools import HoverTool
# Out:
# C:\WPy-3670\python-3.6.7.amd64\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# [COVID Github Page](https://github.com/CSSEGISandData/COVID-19)

# %%
url =  "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"
url2 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv"
#url3 = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv"

covx = pd.read_csv(url,index_col=0,parse_dates=[0])
covy = pd.read_csv(url2,index_col=0,parse_dates=[0])
#covz = pd.read_csv(url3,index_col=0,parse_dates=[0])

# %%
covx
# Out:
#                        Country/Region        Lat       Long  1/22/20  1/23/20  \
# Province/State
# NaN                       Afghanistan  33.000000  65.000000        0        0
# NaN                           Albania  41.153300  20.168300        0        0
# NaN                           Algeria  28.033900   1.659600        0        0
# NaN                           Andorra  42.506300   1.521800        0        0
# NaN                            Angola -11.202700  17.873900        0        0
# ...                               ...        ...        ...      ...      ...
# NaN                    Western Sahara  24.215500 -12.885800        0        0
# NaN             Sao Tome and Principe   0.186360   6.613081        0        0
# NaN                             Yemen  15.552727  48.516388        0        0
# NaN                           Comoros -11.645500  43.333300        0        0
# NaN                        Tajikistan  38.861034  71.276093        0        0
#
#                 1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  4/21/20  \
# Province/State                                               ...
# NaN                   0        0        0        0        0  ...     1092
# NaN                   0        0        0        0        0  ...      609
# NaN                   0        0        0        0        0  ...     2811
# NaN                   0        0        0        0        0  ...      717
# NaN                   0        0        0        0        0  ...       24
# ...                 ...      ...      ...      ...      ...  ...      ...
# NaN                   0        0        0        0        0  ...        6
# NaN                   0        0        0        0        0  ...        4
# NaN                   0        0        0        0        0  ...        1
# NaN                   0        0        0        0        0  ...        0
# NaN                   0        0        0        0        0  ...        0
#
#                 4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  \
# Province/State
# NaN                1176     1279     1351     1463     1531     1703     1828
# NaN                 634      663      678      712      726      736      750
# NaN                2910     3007     3127     3256     3382     3517     3649
# NaN                 723      723      731      738      738      743      743
# NaN                  25       25       25       25       26       27       27
# ...                 ...      ...      ...      ...      ...      ...      ...
# NaN                   6        6        6        6        6        6        6
# NaN                   4        4        4        4        4        4        8
# NaN                   1        1        1        1        1        1        1
# NaN                   0        0        0        0        0        0        0
# NaN                   0        0        0        0        0        0        0
#
#                 4/29/20  4/30/20
# Province/State
# NaN                1939     2171
# NaN                 766      773
# NaN                3848     4006
# NaN                 743      745
# NaN                  27       27
# ...                 ...      ...
# NaN                   6        6
# NaN                   8       14
# NaN                   6        6
# NaN                   0        1
# NaN                   0       15
#
# [266 rows x 103 columns]

# %%
cov0 = covx.reset_index()
cov0y = covy.reset_index()
#cov0z = covz.reset_index()

# %%
cov0
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# 0          0        0        0        0        0  ...     1092     1176
# 1          0        0        0        0        0  ...      609      634
# 2          0        0        0        0        0  ...     2811     2910
# 3          0        0        0        0        0  ...      717      723
# 4          0        0        0        0        0  ...       24       25
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 261        0        0        0        0        0  ...        6        6
# 262        0        0        0        0        0  ...        4        4
# 263        0        0        0        0        0  ...        1        1
# 264        0        0        0        0        0  ...        0        0
# 265        0        0        0        0        0  ...        0        0
#
#      4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0       1279     1351     1463     1531     1703     1828     1939     2171
# 1        663      678      712      726      736      750      766      773
# 2       3007     3127     3256     3382     3517     3649     3848     4006
# 3        723      731      738      738      743      743      743      745
# 4         25       25       25       26       27       27       27       27
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 
/23/20  4/24/20  4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 35      3720     4017     4233     4480     4696     4850     5165     5355
# 36      1824     1853     1948     1948     1998     2053     2087     2112
# 37        13       13       13       13       13       13       13       13
# 38       262      263      267      271      273      273      275      277
# 39       118      118      118      118      118      118      118      118
# 40       256      256      257      258      258      258      258      258
# 41       827      850      865      873      900      915      935      947
# 42     14068    14550    15012    15568    15970    16500    16978    17395
# 43        26       26       26       26       26       27       27       27
# 44     21838    22616    23267    24109    24983    25761    26610    27550
# 45       331      341      349      353      365      366      383      389
# 133    87026    88194    89328    90481    91472    92584    93657    94640
# 137   189973   192994   195351   197675   199414   201505   203591   205463
# 158    11633    12872    13842    14677    15529    16752    17799    19224
# 205    16755    17567    18177    18640    18926    19621    20302    21092
# 217       99       99      109      109      110      110      111      114
# 218       66       70       70       70       70       70       73       73
# 219      521      523      525      525      525      530      537      537
# 220      133      133      136      141      141      141      141      144
# 221      307      308      308      308      308      309      313      315
# 222       11       11       11       11       11       11       11       11
# 223   138078   143464   148377   152840   157149   161145   165221   171253
# 225   869170   905358   938154   965785   988197  1012582  1039909  1069424
# 231        0        0        0        0        0        0        0        0
# 238        0        0        0        0        0        0        0        0
# 245        5        5        5        5        5        5        5        5
# 246       11       11       11       11       11       11       11       11
# 249        3        3        3        3        3        3        3        3
# 250        5        5        6        6        6        6        6        6
# 251       11       11       11       11       12       12       12       12
# 258       12       13       13       13       13       13       13       13
#
# [31 rows x 104 columns]

# %%
#change the file from wide to long
df0 = cov.set_index(['Province/State','Country/Region', 'Lat', 'Long']).stack().reset_index(level=4).reset_index()

# %%
df0
# Out:
#                    Province/State  Country/Region      Lat      Long  level_4  \
# 0                         Alberta          Canada  53.9333 -116.5765  1/22/20
# 1                         Alberta          Canada  53.9333 -116.5765  1/23/20
# 2                         Alberta          Canada  53.9333 -116.5765  1/24/20
# 3                         Alberta          Canada  53.9333 -116.5765  1/25/20
# 4                         Alberta          Canada  53.9333 -116.5765  1/26/20
# ...                           ...             ...      ...       ...      ...
# 3095  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/26/20
# 3096  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/27/20
# 3097  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/28/20
# 3098  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/29/20
# 3099  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/30/20
#
#        0
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# ...   ..
# 3095  13
# 3096  13
# 3097  13
# 3098  13
# 3099  13
#
# [3100 rows x 6 columns]

# %%
df = df0[df0[0]>=1]

# %%
df
# Out:
#                    Province/State  Country/Region      Lat      Long  level_4  \
# 44                        Alberta          Canada  53.9333 -116.5765   3/6/20
# 45                        Alberta          Canada  53.9333 -116.5765   3/7/20
# 46                        Alberta          Canada  53.9333 -116.5765   3/8/20
# 47                        Alberta          Canada  53.9333 -116.5765   3/9/20
# 48                        Alberta          Canada  53.9333 -116.5765  3/10/20
# ...                           ...             ...      ...       ...      ...
# 3095  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/26/20
# 3096  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/27/20
# 3097  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/28/20
# 3098  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/29/20
# 3099  Falkland Islands (Malvinas)  United Kingdom -51.7963  -59.5236  4/30/20
#
#        0
# 44     1
# 45     2
# 46     4
# 47     7
# 48     7
# ...   ..
# 3095  13
# 3096  13
# 3097  13
# 3098  13
# 3099  13
#
# [1644 rows x 6 columns]

# %%
#convert the date from text to date format
df['date'] = pd.to_datetime(df['level_4'])
df['value'] = df[0]
# Out:
# C:\WPy-3670\python-3.6.7.amd64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\WPy-3670\python-3.6.7.amd64\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['date'].max()
# Out:
# Timestamp('2020-04-30 00:00:00')

# %%
#drop the province varible
df.drop(['Province/State', 'level_4', 0, 'Lat', 'Long' ], inplace=True, axis=1)

# %%
df
# Out:
#       Country/Region       date  value
# 44            Canada 2020-03-06      1
# 45            Canada 2020-03-07      2
# 46            Canada 2020-03-08      4
# 47            Canada 2020-03-09      7
# 48            Canada 2020-03-10      7
# ...              ...        ...    ...
# 3095  United Kingdom 2020-04-26     13
# 3096  United Kingdom 2020-04-27     13
# 3097  United Kingdom 2020-04-28     13
# 3098  United Kingdom 2020-04-29     13
# 3099  United Kingdom 2020-04-30     13
#
# [1644 rows x 3 columns]

# %%
#sum up country numbers
df2 = df.groupby(['Country/Region', 'date']).sum().reset_index()

# %%
df2
# Out:
#      Country/Region       date   value
# 0            Canada 2020-01-26       1
# 1            Canada 2020-01-27       1
# 2            Canada 2020-01-28       2
# 3            Canada 2020-01-29       2
# 4            Canada 2020-01-30       2
# ..              ...        ...     ...
# 599  United Kingdom 2020-04-26  154037
# 600  United Kingdom 2020-04-27  158348
# 601  United Kingdom 2020-04-28  162350
# 602  United Kingdom 2020-04-29  166441
# 603  United Kingdom 2020-04-30  172481
#
# [604 rows x 3 columns]

# %%
plt.figure(figsize=(15, 10))

s = sb.lineplot('date', 'value', data=df2, hue='Country/Region')

plt.title('Total COVID-19 Cases')

plt.show()

# %% [markdown]
# [Seaborn](https://seaborn.pydata.org/index.html)

# %%
country = ['US']

# %%
UScases = df2[(df2['Country/Region'].isin(country))]

# %%
YOUR_FONT_SIZE = '7pt'
#output_file("USCovid.html")

source = ColumnDataSource(UScases)

p = figure(x_axis_type="datetime", plot_width=750, plot_height=300)

p.circle(x='date', y='value', source=UScases, color = 'blue', size = 6)
p.line(x='date', y='value', line_width = 1, source=UScases, color = 'blue')
p.legend.location = 'bottom_right'

p.add_tools(HoverTool(
    tooltips=[
        ( 'date',   '@date{%F}'),
        ( '# of Cases', '@value'),
    ],

    formatters={
        'date'      : 'datetime', # use 'datetime' formatter for 'date' field
      },

    # display a tooltip whenever the cursor is vertically in line with a glyph
    mode='vline'
))

p.xaxis[0].axis_label = 'Date'
p.yaxis[0].axis_label = '# of Cases (cumulative)'


#p.add_layout(Title(text=market), 'above')
p.add_layout(Title(text=('Covid-19 Cases - Linear Scale' + '-Country = ' + country[0])), 'above')

show(p)

# %%
YOUR_FONT_SIZE = '7pt'
output_file("USCovid.html")

source = ColumnDataSource(UScases)

p = figure(x_axis_type="datetime", y_axis_type="log", plot_width=750, plot_height=300)

p.circle(x='date', y='value', source=UScases, color = 'blue', size = 6)
p.line(x='date', y='value', line_width = 1, source=UScases, color = 'blue')
p.legend.location = 'bottom_right'

p.add_tools(HoverTool(
    tooltips=[
        ( 'date',   '@date{%F}'),
        ( '# of Cases', '@value'),
    ],

    formatters={
        'date'      : 'datetime', # use 'datetime' formatter for 'date' field
      },

    # display a tooltip whenever the cursor is vertically in line with a glyph
    mode='vline'
))

p.xaxis[0].axis_label = 'Date'
p.yaxis[0].axis_label = '# of Cases (cumulative)'


#p.add_layout(Title(text=market), 'above')
p.add_layout(Title(text='Covid-19 Cases - Logrithmic Scale' + '-Country = ' + country[0]), 'above')


show(p)

# %% [markdown]
# [Bokeh Visualization](https://docs.bokeh.org/en/latest/index.html#)

# %% [markdown]
# [Covid 19 Tracker](https://www.worldometers.info/coronavirus/country/us/)
